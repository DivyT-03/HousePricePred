# %% [markdown]
# # House Rent Prediction Model  Using Python

# %% [markdown]
# The House Price Dataset is taken from Kaggle : House Prices - Advanced Regression Techniques<br>
# Link: https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Preprocessing

# %%
#Reading DataSet
df=pd.read_csv('C:\\Users\\inasu\\Downloads\\House\\train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
print("The dataset is of shape",df.shape)
# Out:
# The dataset is of shape (1460, 81)

# %% [markdown]
# We drop all the Columns with more than 500 Null Values. As they won't add much value to our prediction.

# %%
df=df.drop([df.columns[j] for j,i in enumerate(list(df.isnull().sum())) if i>500],axis=1)

# %% [markdown]
# We fill in the Null values with the mean values of the Int/Float Columns

# %%
df.fillna(df.mean(),inplace=True)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    AllPub    Inside  ...             0         0           0        0
# 1    AllPub       FR2  ...             0         0           0        0
# 2    AllPub    Inside  ...             0         0           0        0
# 3    AllPub    Corner  ...           272         0           0        0
# 4    AllPub       FR2  ...             0         0           0        0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ## Data Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Heatmap to observe the coorelation between the colums

# %%
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %% [markdown]
# We drop the columns with a corr less than 0.3 as they are weak

# %%
df=df.drop([df.columns[j] for j,i in enumerate(list(df.corr()["SalePrice"])) if i<0.3 and i>-0.3],axis=1)

# %%
df.head()
# Out:
#   MSZoning  LotArea LotShape LandContour Utilities LotConfig Condition1  \
# 0       RL     8450      Reg         Lvl    AllPub    Inside       Norm
# 1       RL     9600      Reg         Lvl    AllPub       FR2      Feedr
# 2       RL    11250      IR1         Lvl    AllPub    Inside       Norm
# 3       RL     9550      IR1         Lvl    AllPub    Corner       Norm
# 4       RL    14260      IR1         Lvl    AllPub       FR2       Norm
#
#   Condition2 BldgType  OverallQual  ...  EnclosedPorch 3SsnPorch ScreenPorch  \
# 0       Norm     1Fam            7  ...              0         0           0
# 1       Norm     1Fam            6  ...              0         0           0
# 2       Norm     1Fam            7  ...              0         0           0
# 3       Norm     1Fam            7  ...            272         0           0
# 4       Norm     1Fam            8  ...              0         0           0
#
#    PoolArea MiscVal MoSold YrSold SaleType  SaleCondition SalePrice
# ...

# %% [markdown]
# For the categorical values, we use pandas get_dummies to fill in the dummy values.

# %%
df_dummies=pd.get_dummies(df)

# %%
df_dummies.head()
# Out:
#    LotArea  OverallQual  YearRemodAdd  MasVnrArea  TotalBsmtSF  1stFlrSF  \
# 0     8450            7          2003       196.0          856       856
# 1     9600            6          1976         0.0         1262      1262
# 2    11250            7          2002       162.0          920       920
# 3     9550            7          1970         0.0          756       961
# 4    14260            8          2000       350.0         1145      1145
#
#    2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  ...  SaleType_ConLw  \
# 0       854             0       1710             1  ...               0
# 1         0             0       1262             0  ...               0
# 2       866             0       1786             1  ...               0
# 3       756             0       1717             1  ...               0
# 4      1053             0       2198             1  ...               0
#
#    SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_Abnorml  \
# ...

# %% [markdown]
# ## Prediction

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
cols=list(df_dummies.columns)
cols.remove('SalePrice')
X_train, X_test, y_train, y_test = train_test_split(df_dummies[cols], df_dummies['SalePrice'], test_size=0.33, random_state=42)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
r_sq = model.score(df_dummies[cols],df_dummies['SalePrice'])
print("Score of the model is:",r_sq,"with the intercept:",model.intercept_,"and coefficients:\n",model.coef_)
intercept=model.intercept_
coef=model.coef_
# Out:
# Score of the model is: 0.8524920164038653 with the intercept: 666951.4994856212 and coefficients:
#  [ 3.61954232e-01  1.20667576e+04  9.51693596e+01  4.26889052e+01
#  -1.82687584e+00  1.63124479e+01  3.21675528e+00  9.02253568e+00
#   2.85517359e+01  1.24634728e+04  1.93000989e+03  7.68768816e+03
#   1.84509871e+03 -4.76655048e+03 -1.73300191e+04  3.04100556e+03
#   3.31433389e+03 -1.60621146e+02  1.29017028e+04  1.34912075e+01
#   2.42582499e+01 -1.26430647e+01  2.17839051e+01  4.39543709e+01
#   6.98481205e+01 -1.84813583e+02  2.64478816e+00 -1.94314450e+02
#  -3.06403271e+02 -2.23968490e+04  9.09728387e+03  7.11754402e+03
#   7.86842600e+03 -1.68640489e+03  9.91569436e+03  1.36014845e+04
#  -3.36705088e+04  1.01533299e+04 -2.20544331e+04  1.97025801e+04
#   6.99933487e+03 -4.64748190e+03  3.40815806e+04 -3.40815806e+04
#  -5.20865277e+03  1.00935762e+04 -6.51519158e+03  3.66888751e+03
#  -2.03861934e+03 -9.81005230e+03 -3.40930049e+03  9.66324658e+03
# ...

# %%
y_hat = model.predict(X_test)

# %%
from sklearn.metrics import f1_score,jaccard_score,recall_score,accuracy_score,r2_score
from sklearn import metrics
RSS=np.mean((y_test-y_hat)**2)
VS=model.score(X_test,y_test)
MAE=np.mean(np.absolute(y_test-y_hat))
R2=r2_score(y_test,y_hat)
MSE=np.sqrt(metrics.mean_squared_error(y_test,y_hat))

# %%
print("RSS=",RSS,"\nVS=",VS,"\nMAE=",MAE,"\nR2=",R2,"\nMSE=",MSE)
# Out:
# RSS= 1427733902.6383371
# VS= 0.8055227091826005
# MAE= 22570.1171770562
# R2= 0.8055227091826005
# MSE= 37785.36624989016
